# %%
# Importação das bibliotecas Python
import os
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# Importação das bibiotecas do Sklearn
from sklearn.preprocessing import LabelEncoder

# %%
# Importação das bibliotecas Graficas
import seaborn as sns
#import scikitplot as skplt
import matplotlib.pyplot as plt

# Exibe gráficos na página (inline)
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#pd.options.display.max_columns = 116
#pd.options.display.max_rows = 116

# %% [markdown]
# ## Funções do Sistema

# %%
def get_attacks(dir, dev_name, attack, label):
    
    # Lista para armazenar os DataFrames processados
    dfs_processados = []

    # Percorre todos os arquivos no diretório
    for file in os.listdir(dir):
        # Verifica se o arquivo tem a extensão .csv
        if file.endswith('.csv'):
            # Caminho completo do arquivo
            full_path = os.path.join(dir, file)
            # Lê o arquivo CSV e armazena em um DataFrame
            df = pd.read_csv(full_path)
            
            # Adiciona colunas fixas
            df['Device_Name'] = dev_name
            df['Attack'] = attack
            
            # Adiciona uma nova coluna com o nome do arquivo (sem a extensão .csv)
            df['Attack_subType'] = os.path.splitext(file)[0]
            
            # Adiciona a coluna 'label'
            df['label'] = label
            
            # Adiciona o DataFrame processado à lista
            dfs_processados.append(df)

    return dfs_processados

# %%
def get_normal(dir, dev_name, attack, label):

    # Lista para armazenar os DataFrames processados
    df_normal = []

    # Construindo o caminho completo do arquivo de forma segura
    file_path = os.path.join(dir, 'benign_traffic.csv')

    # Lendo o arquivo CSV
    df = pd.read_csv(file_path)
    
    # Adicionando as colunas com os valores dos parâmetros
    df['Device_Name'] = dev_name  # Usando o parâmetro dev_name
    df['Attack'] = attack  # Usando o parâmetro attack
    df['Attack_subType'] = 'Normal'  # Subcategoria, fixa como 'Normal'
    df['label'] = label  # Usando o parâmetro label

    # Adicionando o DataFrame configurado à lista
    df_normal.append(df)

    return df_normal

# %% [markdown]
# ## Lendo dataset de trafego normal

# %%
source = '../datasets/detectBbaiot/Ecobee_Thermostat/'
device = 'Ecobee_Thermostat'
attack = 'Normal'
label = 'Normal'

normal_temp = get_normal(source, device, attack, label)
normal = pd.concat(normal_temp, ignore_index=True)
normal.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      110.000000            0.000000          1.000000
# 2          1.724055       91.439104          249.441812          1.823878
# 3          1.000000      342.000000            0.000000          1.000000
# 4          2.516815       90.867308          150.827639          2.688981
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      110.000000            0.000000          1.000000      110.000000
# 2       92.454965          253.612868          1.937463       93.483558
# 3      342.000000            0.000000          1.000000      342.000000
# 4       91.541993          160.705060          2.888469       92.277536
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...        60.000000
# 1            0.000000            1.000000  ...       106.146795
# 2          255.733288            1.993563  ...        78.000000
# 3            0.000000            1.000000  ...       341.959189
# 4          169.944112            2.988463  ...        98.930412
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0        0.000000             60.000000           0.000000
# 1        7.887770            106.146795          62.216910
# 2        0.000000             78.000000           0.000000
# 3        7.347919            341.959189          53.991908
# 4        9.942635             98.930412          98.855983
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc        Device_Name  Attack  \
# 0                    0.0             0.0  Ecobee_Thermostat  Normal
# 1                    0.0             0.0  Ecobee_Thermostat  Normal
# 2                    0.0             0.0  Ecobee_Thermostat  Normal
# 3                    0.0             0.0  Ecobee_Thermostat  Normal
# 4                    0.0             0.0  Ecobee_Thermostat  Normal
#
#    Attack_subType   label
# 0          Normal  Normal
# 1          Normal  Normal
# 2          Normal  Normal
# 3          Normal  Normal
# 4          Normal  Normal
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Tratando dataset ataques - Gafgyt

# %%
source = '../datasets/detectBbaiot/Ecobee_Thermostat/gafgyt_attacks/'
device = 'Ecobee_Thermostat'
attack = 'gafgyt'
label = 'Anomaly'

gafgyt_temp = get_attacks(source, device, attack, label)
gafgyt = pd.concat(gafgyt_temp, ignore_index=True)
gafgyt.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       98.000000        0.000000e+00          1.000000
# 1          1.027124       98.000000        1.818989e-12          1.114820
# 2          1.029968       98.000000        0.000000e+00          1.133728
# 3          1.338152       74.086423        1.933753e+02          1.581141
# 4          2.311785       74.049039        1.097295e+02          2.562374
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       98.000000        0.000000e+00          1.000000       98.000000
# 1       98.000000        1.818989e-12          1.486040       98.000000
# 2       98.000000        3.637979e-12          1.732886       98.000000
# 3       77.761456        2.380347e+02          2.386844       84.593174
# 4       76.293499        1.485053e+02          3.377363       81.456652
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...         98.00000
# 1            0.000000            1.930395  ...         98.00000
# 2            0.000000            2.798650  ...         98.00000
# 3          249.275446            3.736997  ...         66.00000
# 4          198.855685            4.735510  ...         70.00008
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0             0.0             98.000000       0.000000e+00
# 1             0.0            138.592929       0.000000e+00
# 2             0.0            138.592929       5.456968e-12
# 3             0.0            102.941731       0.000000e+00
# 4             4.0            105.550988       1.600000e+01
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc        Device_Name  Attack  \
# 0                    0.0             0.0  Ecobee_Thermostat  gafgyt
# 1                    0.0             0.0  Ecobee_Thermostat  gafgyt
# 2                    0.0             0.0  Ecobee_Thermostat  gafgyt
# 3                    0.0             0.0  Ecobee_Thermostat  gafgyt
# 4                    0.0             0.0  Ecobee_Thermostat  gafgyt
#
#    Attack_subType    label
# 0            scan  Anomaly
# 1            scan  Anomaly
# 2            scan  Anomaly
# 3            scan  Anomaly
# 4            scan  Anomaly
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Tratando dataset ataques - Mirai

# %%
source = '../datasets/detectBbaiot/Ecobee_Thermostat/mirai_attacks/'
device = 'Ecobee_Thermostat'
attack = 'mirai'
label = 'Anomaly'

mirai_temp = get_attacks(source, device, attack, label)
mirai = pd.concat(mirai_temp, ignore_index=True)
mirai.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000            74.0        0.000000e+00          1.000000
# 1          1.995653            74.0        0.000000e+00          1.997390
# 2          2.984032            74.0        0.000000e+00          2.990403
# 3          3.952494            74.0        0.000000e+00          3.971399
# 4          4.931439            74.0        9.094947e-13          4.958692
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0            74.0        0.000000e+00          1.000000            74.0
# 1            74.0        1.818989e-12          1.999129            74.0
# 2            74.0        1.818989e-12          2.996795            74.0
# 3            74.0        1.818989e-12          3.990434            74.0
# 4            74.0        1.818989e-12          4.986173            74.0
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0        0.000000e+00            1.000000  ...             74.0
# 1        0.000000e+00            1.999913  ...             74.0
# 2        9.094947e-13            2.999679  ...             74.0
# 3        0.000000e+00            3.999042  ...             74.0
# 4        9.094947e-13            4.998615  ...             74.0
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0             0.0                  74.0                0.0
# 1             0.0                  74.0                0.0
# 2             0.0                  74.0                0.0
# 3             0.0                  74.0                0.0
# 4             0.0                  74.0                0.0
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc        Device_Name  Attack  \
# 0                    0.0             0.0  Ecobee_Thermostat   mirai
# 1                    0.0             0.0  Ecobee_Thermostat   mirai
# 2                    0.0             0.0  Ecobee_Thermostat   mirai
# 3                    0.0             0.0  Ecobee_Thermostat   mirai
# 4                    0.0             0.0  Ecobee_Thermostat   mirai
#
#    Attack_subType    label
# 0             syn  Anomaly
# 1             syn  Anomaly
# 2             syn  Anomaly
# 3             syn  Anomaly
# 4             syn  Anomaly
#
# [5 rows x 119 columns]

# %% [markdown]
# ### Concatenando os dataframes

# %%
df_Temp = pd.concat([normal, gafgyt, mirai], ignore_index=True)

#Embaralhando as linhas do DataFrame com base no índice aleatório
df = df_Temp.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1         95.468705      418.025972        48672.196392        178.338225
# 2          1.434817      161.156751        20824.412520          1.606714
# 3          1.000000       60.000000            0.000000          1.000000
# 4        158.426252       68.702413           46.101791        248.074042
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      400.683865        52214.160130        620.006546      413.451070
# 2      184.570048        23172.138780          1.846567      209.954713
# 3       60.000000            0.000000          1.000000       60.000000
# 4       69.697735           41.722228        725.998074       70.688852
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...        60.000000
# 1        49659.415371         6419.813931  ...       554.000000
# 2        24478.820490            2.087962  ...       232.221767
# 3            0.000000            1.000000  ...        60.000000
# 4           35.392372         6903.054393  ...        74.000000
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0        0.000000             60.000000            0.00000
# 1        0.000000            554.000000            0.00000
# 2      152.731445            353.408839        33797.93665
# 3        0.000000             60.000000            0.00000
# 4        0.000000             74.000000            0.00000
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc        Device_Name  Attack  \
# 0               0.000000        0.000000  Ecobee_Thermostat  gafgyt
# 1               0.000000        0.000000  Ecobee_Thermostat   mirai
# 2           -4322.953551       -0.180987  Ecobee_Thermostat  Normal
# 3               0.000000        0.000000  Ecobee_Thermostat  gafgyt
# 4               0.000000        0.000000  Ecobee_Thermostat   mirai
#
#    Attack_subType    label
# 0             udp  Anomaly
# 1             udp  Anomaly
# 2          Normal   Normal
# 3             tcp  Anomaly
# 4             syn  Anomaly
#
# [5 rows x 119 columns]

# %%
df.to_csv('../datasets/dacoga/dsetET.csv', index=False)
