# %%
# Importação das bibliotecas Python
import os
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# Importação das bibiotecas do Sklearn
from sklearn.preprocessing import LabelEncoder

# %%
# Importação das bibliotecas Graficas
import seaborn as sns
#import scikitplot as skplt
import matplotlib.pyplot as plt

# Exibe gráficos na página (inline)
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#pd.options.display.max_columns = 116
#pd.options.display.max_rows = 116

# %% [markdown]
# ## Funções do Sistema

# %%
def get_attacks(dir, dev_name, attack, label):
    
    # Lista para armazenar os DataFrames processados
    dfs_processados = []

    # Percorre todos os arquivos no diretório
    for file in os.listdir(dir):
        # Verifica se o arquivo tem a extensão .csv
        if file.endswith('.csv'):
            # Caminho completo do arquivo
            full_path = os.path.join(dir, file)
            # Lê o arquivo CSV e armazena em um DataFrame
            df = pd.read_csv(full_path)
            
            # Adiciona colunas fixas
            df['Device_Name'] = dev_name
            df['Attack'] = attack
            
            # Adiciona uma nova coluna com o nome do arquivo (sem a extensão .csv)
            df['Attack_subType'] = os.path.splitext(file)[0]
            
            # Adiciona a coluna 'label'
            df['label'] = label
            
            # Adiciona o DataFrame processado à lista
            dfs_processados.append(df)

    return dfs_processados

# %%
def get_normal(dir, dev_name, attack, label):

    # Lista para armazenar os DataFrames processados
    df_normal = []

    # Construindo o caminho completo do arquivo de forma segura
    file_path = os.path.join(dir, 'benign_traffic.csv')

    # Lendo o arquivo CSV
    df = pd.read_csv(file_path)
    
    # Adicionando as colunas com os valores dos parâmetros
    df['Device_Name'] = dev_name  # Usando o parâmetro dev_name
    df['Attack'] = attack  # Usando o parâmetro attack
    df['Attack_subType'] = 'Normal'  # Subcategoria, fixa como 'Normal'
    df['label'] = label  # Usando o parâmetro label

    # Adicionando o DataFrame configurado à lista
    df_normal.append(df)

    return df_normal

# %% [markdown]
# ## Lendo dataset de trafego normal

# %%
source = '../datasets/detectBbaiot/Provision_PT_838_Security_Camera/'
device = 'Provision_PT_838_Security_Camera'
attack = 'Normal'
label = 'Normal'

normal_temp = get_normal(source, device, attack, label)
normal = pd.concat(normal_temp, ignore_index=True)
normal.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000        0.000000e+00          1.000000
# 1          1.000000      590.000000        0.000000e+00          1.000000
# 2          1.956973      590.000000        5.820000e-11          1.973957
# 3          1.000000       60.000000        0.000000e+00          1.000000
# 4          1.988608       66.034372        3.599882e+01          1.993149
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      590.000000            0.000000          1.000000      590.000000
# 2      590.000000            0.000000          1.991242      590.000000
# 3       60.000000            0.000000          1.000000       60.000000
# 4       66.020623           35.999575          1.997711       66.006874
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...        60.000000
# 1            0.000000            1.000000  ...       443.197258
# 2            0.000000            1.999121  ...       470.101420
# 3            0.000000            1.000000  ...        60.000000
# 4           35.999953            1.999771  ...        72.000000
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0        0.000000             60.000000            0.00000
# 1      121.885335            443.197258        14856.03496
# 2      123.932152            470.101420        15359.17835
# 3        0.000000             60.000000            0.00000
# 4        0.000000             72.000000            0.00000
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                       Device_Name  \
# 0                    0.0             0.0  Provision_PT_838_Security_Camera
# 1                    0.0             0.0  Provision_PT_838_Security_Camera
# 2                    0.0             0.0  Provision_PT_838_Security_Camera
# 3                    0.0             0.0  Provision_PT_838_Security_Camera
# 4                    0.0             0.0  Provision_PT_838_Security_Camera
#
#    Attack  Attack_subType   label
# 0  Normal          Normal  Normal
# 1  Normal          Normal  Normal
# 2  Normal          Normal  Normal
# 3  Normal          Normal  Normal
# 4  Normal          Normal  Normal
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Tratando dataset ataques - Gafgyt

# %%
source = '../datasets/detectBbaiot/Provision_PT_838_Security_Camera/gafgyt_attacks/'
device = 'Provision_PT_838_Security_Camera'
attack = 'gafgyt'
label = 'Anomaly'

gafgyt_temp = get_attacks(source, device, attack, label)
gafgyt = pd.concat(gafgyt_temp, ignore_index=True)
gafgyt.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       98.000000        0.000000e+00          1.000000
# 1          1.027124       98.000000        1.818989e-12          1.114820
# 2          1.029968       98.000000        0.000000e+00          1.133728
# 3          1.338152       74.086423        1.933753e+02          1.581141
# 4          2.311785       74.049039        1.097295e+02          2.562374
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       98.000000        0.000000e+00          1.000000       98.000000
# 1       98.000000        1.818989e-12          1.486040       98.000000
# 2       98.000000        3.637979e-12          1.732886       98.000000
# 3       77.761456        2.380347e+02          2.386844       84.593174
# 4       76.293499        1.485053e+02          3.377363       81.456652
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...         98.00000
# 1            0.000000            1.930395  ...         98.00000
# 2            0.000000            2.798650  ...         98.00000
# 3          249.275446            3.736997  ...         66.00000
# 4          198.855685            4.735510  ...         70.00008
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0             0.0             98.000000       0.000000e+00
# 1             0.0            138.592929       0.000000e+00
# 2             0.0            138.592929       5.456968e-12
# 3             0.0            102.941731       0.000000e+00
# 4             4.0            105.550988       1.600000e+01
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                       Device_Name  \
# 0                    0.0             0.0  Provision_PT_838_Security_Camera
# 1                    0.0             0.0  Provision_PT_838_Security_Camera
# 2                    0.0             0.0  Provision_PT_838_Security_Camera
# 3                    0.0             0.0  Provision_PT_838_Security_Camera
# 4                    0.0             0.0  Provision_PT_838_Security_Camera
#
#    Attack  Attack_subType    label
# 0  gafgyt            scan  Anomaly
# 1  gafgyt            scan  Anomaly
# 2  gafgyt            scan  Anomaly
# 3  gafgyt            scan  Anomaly
# 4  gafgyt            scan  Anomaly
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Tratando dataset ataques - Mirai

# %%
source = '../datasets/detectBbaiot/Provision_PT_838_Security_Camera/mirai_attacks/'
device = 'Provision_PT_838_Security_Camera'
attack = 'mirai'
label = 'Anomaly'

mirai_temp = get_attacks(source, device, attack, label)
mirai = pd.concat(mirai_temp, ignore_index=True)
mirai.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000        0.000000e+00          1.000000
# 1          1.999993       60.000000        4.547474e-13          1.999996
# 2          2.440500       60.000000        9.094947e-13          2.642555
# 3          3.424046       60.000000        1.364242e-12          3.631851
# 4          4.424035       63.164532        3.428919e+01          4.631844
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000        0.000000e+00          1.000000       60.000000
# 1       60.000000        4.547474e-13          1.999999       60.000000
# 2       60.000000        9.094947e-13          2.872952       60.000000
# 3       60.000000        9.094947e-13          3.869068       60.000000
# 4       63.022554        3.317993e+01          4.869065       62.875295
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0        0.000000e+00            1.000000  ...             60.0
# 1        4.547474e-13            2.000000  ...             60.0
# 2        4.547474e-13            2.986917  ...             60.0
# 3        4.547474e-13            3.986513  ...             60.0
# 4        3.198681e+01            4.986512  ...             74.0
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0             0.0                  60.0                0.0
# 1             0.0                  60.0                0.0
# 2             0.0                  60.0                0.0
# 3             0.0                  60.0                0.0
# 4             0.0                  74.0                0.0
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                       Device_Name  \
# 0                    0.0             0.0  Provision_PT_838_Security_Camera
# 1                    0.0             0.0  Provision_PT_838_Security_Camera
# 2                    0.0             0.0  Provision_PT_838_Security_Camera
# 3                    0.0             0.0  Provision_PT_838_Security_Camera
# 4                    0.0             0.0  Provision_PT_838_Security_Camera
#
#    Attack  Attack_subType    label
# 0   mirai             syn  Anomaly
# 1   mirai             syn  Anomaly
# 2   mirai             syn  Anomaly
# 3   mirai             syn  Anomaly
# 4   mirai             syn  Anomaly
#
# [5 rows x 119 columns]

# %% [markdown]
# ### Concatenando os dataframes

# %%
df_Temp = pd.concat([normal, gafgyt, mirai], ignore_index=True)

#Embaralhando as linhas do DataFrame com base no índice aleatório
df = df_Temp.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0         34.601760      398.908959        52550.382469         67.717384
# 1        166.897264       74.093675            2.239427        271.018503
# 2          1.000000       60.000000            0.000000          1.000000
# 3         81.573509      361.922677        57800.777918        138.807560
# 4        142.893002       65.017844           45.078160        202.254552
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0      403.302501        51712.306449        290.361681      371.306909
# 1       74.076204            1.823122        802.782759       74.053501
# 2       60.000000            0.000000          1.000000       60.000000
# 3      321.869667        60673.771150        426.539988      314.707208
# 4       65.919080           47.843152        449.879100       67.102984
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0        56847.712817         3664.475330  ...             60.0
# 1            1.405218         7073.265995  ...             74.0
# 2            0.000000            1.000000  ...             60.0
# 3        60910.274988         3941.072685  ...            554.0
# 4           49.018986         3714.410039  ...             60.0
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0    0.000000e+00             60.000000       0.000000e+00
# 1    9.536743e-07             95.268043       9.094947e-13
# 2    0.000000e+00             60.000000       0.000000e+00
# 3    0.000000e+00            554.000000       0.000000e+00
# 4    0.000000e+00             60.000000       0.000000e+00
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                       Device_Name  \
# 0                    0.0             0.0  Provision_PT_838_Security_Camera
# 1                    0.0             0.0  Provision_PT_838_Security_Camera
# 2                    0.0             0.0  Provision_PT_838_Security_Camera
# 3                    0.0             0.0  Provision_PT_838_Security_Camera
# 4                    0.0             0.0  Provision_PT_838_Security_Camera
#
#    Attack  Attack_subType    label
# 0   mirai             udp  Anomaly
# 1  gafgyt           combo  Anomaly
# 2  gafgyt             tcp  Anomaly
# 3   mirai             udp  Anomaly
# 4   mirai             syn  Anomaly
#
# [5 rows x 119 columns]

# %%
df.to_csv('../datasets/dacoga/dsetPT838.csv', index=False)
