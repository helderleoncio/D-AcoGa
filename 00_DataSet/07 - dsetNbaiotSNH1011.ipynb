# %%
# Importação das bibliotecas Python
import os
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# Importação das bibiotecas do Sklearn
from sklearn.preprocessing import LabelEncoder

# %%
# Importação das bibliotecas Graficas
import seaborn as sns
#import scikitplot as skplt
import matplotlib.pyplot as plt

# Exibe gráficos na página (inline)
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#pd.options.display.max_columns = 116
#pd.options.display.max_rows = 116

# %% [markdown]
# ## Funções do Sistema

# %%
def get_attacks(dir, dev_name, attack, label):
    
    # Lista para armazenar os DataFrames processados
    dfs_processados = []

    # Percorre todos os arquivos no diretório
    for file in os.listdir(dir):
        # Verifica se o arquivo tem a extensão .csv
        if file.endswith('.csv'):
            # Caminho completo do arquivo
            full_path = os.path.join(dir, file)
            # Lê o arquivo CSV e armazena em um DataFrame
            df = pd.read_csv(full_path)
            
            # Adiciona colunas fixas
            df['Device_Name'] = dev_name
            df['Attack'] = attack
            
            # Adiciona uma nova coluna com o nome do arquivo (sem a extensão .csv)
            df['Attack_subType'] = os.path.splitext(file)[0]
            
            # Adiciona a coluna 'label'
            df['label'] = label
            
            # Adiciona o DataFrame processado à lista
            dfs_processados.append(df)

    return dfs_processados

# %%
def get_normal(dir, dev_name, attack, label):

    # Lista para armazenar os DataFrames processados
    df_normal = []

    # Construindo o caminho completo do arquivo de forma segura
    file_path = os.path.join(dir, 'benign_traffic.csv')

    # Lendo o arquivo CSV
    df = pd.read_csv(file_path)
    
    # Adicionando as colunas com os valores dos parâmetros
    df['Device_Name'] = dev_name  # Usando o parâmetro dev_name
    df['Attack'] = attack  # Usando o parâmetro attack
    df['Attack_subType'] = 'Normal'  # Subcategoria, fixa como 'Normal'
    df['label'] = label  # Usando o parâmetro label

    # Adicionando o DataFrame configurado à lista
    df_normal.append(df)

    return df_normal

# %% [markdown]
# ## Lendo dataset de trafego normal

# %%
source = '../datasets/detectBbaiot/Samsung_SNH_1011_N_Webcam/'
device = 'Samsung_SNH_1011_N_Webcam'
attack = 'Normal'
label = 'Normal'

normal_temp = get_normal(source, device, attack, label)
normal = pd.concat(normal_temp, ignore_index=True)
normal.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000       70.000000            0.000000          1.000000
# 2          1.000008       89.999836            0.003289          1.000889
# 3          1.000000      322.000000            0.000000          1.000000
# 4          1.784845      328.723273           35.476876          1.864710
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1       70.000000            0.000000          1.000000       70.000000
# 2       89.982231            0.355061          1.096162       88.245473
# 3      322.000000            0.000000          1.000000      322.000000
# 4      328.435318           35.810498          1.952701      328.145333
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...        60.000000
# 1            0.000000            1.000000  ...        70.000000
# 2           32.012169            1.791226  ...        90.000000
# 3            0.000000            1.000000  ...       380.087760
# 4           35.978878            1.995166  ...       376.297073
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0        0.000000             60.000000           0.000000
# 1        0.000000             70.000000           0.000000
# 2        0.000000             90.000000           0.000000
# 3       92.127549            380.087760        8487.485312
# 4       89.161260            376.297073        7949.730316
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                Device_Name  Attack  \
# 0                    0.0             0.0  Samsung_SNH_1011_N_Webcam  Normal
# 1                    0.0             0.0  Samsung_SNH_1011_N_Webcam  Normal
# 2                    0.0             0.0  Samsung_SNH_1011_N_Webcam  Normal
# 3                    0.0             0.0  Samsung_SNH_1011_N_Webcam  Normal
# 4                    0.0             0.0  Samsung_SNH_1011_N_Webcam  Normal
#
#    Attack_subType   label
# 0          Normal  Normal
# 1          Normal  Normal
# 2          Normal  Normal
# 3          Normal  Normal
# 4          Normal  Normal
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Tratando dataset ataques - Gafgyt

# %%
source = '../datasets/detectBbaiot/Samsung_SNH_1011_N_Webcam/gafgyt_attacks/'
device = 'Samsung_SNH_1011_N_Webcam'
attack = 'gafgyt'
label = 'Anomaly'

gafgyt_temp = get_attacks(source, device, attack, label)
gafgyt = pd.concat(gafgyt_temp, ignore_index=True)
gafgyt.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       98.000000        0.000000e+00          1.000000
# 1          1.027124       98.000000        1.818989e-12          1.114820
# 2          1.029968       98.000000        0.000000e+00          1.133728
# 3          1.338152       74.086423        1.933753e+02          1.581141
# 4          2.311785       74.049039        1.097295e+02          2.562374
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       98.000000        0.000000e+00          1.000000       98.000000
# 1       98.000000        1.818989e-12          1.486040       98.000000
# 2       98.000000        3.637979e-12          1.732886       98.000000
# 3       77.761456        2.380347e+02          2.386844       84.593174
# 4       76.293499        1.485053e+02          3.377363       81.456652
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000            1.000000  ...         98.00000
# 1            0.000000            1.930395  ...         98.00000
# 2            0.000000            2.798650  ...         98.00000
# 3          249.275446            3.736997  ...         66.00000
# 4          198.855685            4.735510  ...         70.00008
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0             0.0             98.000000       0.000000e+00
# 1             0.0            138.592929       0.000000e+00
# 2             0.0            138.592929       5.456968e-12
# 3             0.0            102.941731       0.000000e+00
# 4             4.0            105.550988       1.600000e+01
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                Device_Name  Attack  \
# 0                    0.0             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 1                    0.0             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 2                    0.0             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 3                    0.0             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 4                    0.0             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
#
#    Attack_subType    label
# 0            scan  Anomaly
# 1            scan  Anomaly
# 2            scan  Anomaly
# 3            scan  Anomaly
# 4            scan  Anomaly
#
# [5 rows x 119 columns]

# %% [markdown]
# ### Concatenando os dataframes

# %%
df_Temp = pd.concat([normal, gafgyt], ignore_index=True)

#Embaralhando as linhas do DataFrame com base no índice aleatório
df = df_Temp.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0               1.0       60.000000            0.000000          1.000000
# 1               1.0       60.000000            0.000000          1.000000
# 2               1.0       60.000000            0.000000          1.000000
# 3               1.0       60.000000            0.000000          1.000000
# 4               1.0       60.000002            0.000239          1.000047
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1       60.000000            0.000000          1.000000       60.000000
# 2       60.000000            0.000000          1.000000       60.000000
# 3       60.000000            0.000000          1.000000       60.000000
# 4       60.002656            0.357775          1.057382       63.911445
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.01_mean  \
# 0            0.000000             1.00000  ...             60.0
# 1            0.000000             1.00000  ...             60.0
# 2            0.000000             1.00000  ...             60.0
# 3            0.000000             1.00000  ...             60.0
# 4          579.424328             4.15511  ...             60.0
#
#    HpHp_L0.01_std  HpHp_L0.01_magnitude  HpHp_L0.01_radius  \
# 0             0.0             60.000000       0.000000e+00
# 1             0.0             60.000000       0.000000e+00
# 2             0.0             60.000000       0.000000e+00
# 3             0.0             60.000000       0.000000e+00
# 4             0.0             84.852814       9.090000e-13
#
#    HpHp_L0.01_covariance  HpHp_L0.01_pcc                Device_Name  Attack  \
# 0           0.000000e+00             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 1           0.000000e+00             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 2           0.000000e+00             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 3           0.000000e+00             0.0  Samsung_SNH_1011_N_Webcam  gafgyt
# 4          -1.300000e-29             0.0  Samsung_SNH_1011_N_Webcam  Normal
#
#    Attack_subType    label
# 0             udp  Anomaly
# 1             udp  Anomaly
# 2             udp  Anomaly
# 3             tcp  Anomaly
# 4          Normal   Normal
#
# [5 rows x 119 columns]

# %%
df.to_csv('../datasets/dacoga/dsetSNH1011.csv', index=False)
